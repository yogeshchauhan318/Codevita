# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **Name: Yogesh chauhan**

# %% [markdown]
# **Task: 3**

# %% [markdown]
# **Importing necassary dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/train-eda/train.csv

# %% [markdown]
# **Loading Dataset**

# %%
train = pd.read_csv("../input/train-eda/train.csv")

# %%
train.head(5)
# Out:
#    Train_No    Train_Name Source_Station_Name  \
# 0       107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1       108  VLNK-MAO-SWV         MADGOAN JN.
# 2       128  MAO-KOP SPEC         MADGOAN JN.
# 3       290  PALACE ON WH   DELHI-SAFDAR JANG
# 4       401  BSB BHARATDA          AURANGABAD
#
#              Destination_Station_Name       Days  Speed_km_hr  \
# 0                         MADGOAN JN.   Saturday          120
# 1                     SAWANTWADI ROAD     Friday          110
# 2  CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday           70
# 3                   DELHI-SAFDAR JANG  Wednesday           60
# 4                        VARANASI JN.   Saturday           75
#
#    DecayOrAccidents  Passenger_satisfaction  %_seat_occupied
# 0                 7                      75               86
# 1                 6                      80               50
# 2                 5                      62               62
# 3                 4                      56               90
# ...

# %%
train.shape
# Out:
# (49, 9)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Train_No                  49 non-null     int64
#  1   Train_Name                49 non-null     object
#  2   Source_Station_Name       49 non-null     object
#  3   Destination_Station_Name  49 non-null     object
#  4   Days                      49 non-null     object
#  5   Speed_km_hr               49 non-null     int64
#  6   DecayOrAccidents          49 non-null     int64
#  7   Passenger_satisfaction    49 non-null     int64
#  8   %_seat_occupied           49 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 3.6+ KB

# %%
train.describe()
# Out:
#            Train_No  Speed_km_hr  DecayOrAccidents  Passenger_satisfaction  \
# count     49.000000    49.000000         49.000000               49.000000
# mean    1964.897959   106.265306          7.346939               67.816327
# std     3121.409552    33.355269          2.376544               23.267174
# min      107.000000    55.000000          4.000000               10.000000
# 25%      604.000000    79.000000          6.000000               52.000000
# 50%     1655.000000   110.000000          7.000000               75.000000
# 75%     2515.000000   125.000000          8.000000               85.000000
# max    22439.000000   231.000000         15.000000              100.000000
#
#        %_seat_occupied
# count        49.000000
# mean         79.959184
# std          16.248024
# min          10.000000
# 25%          70.000000
# 50%          80.000000
# 75%          90.000000
# max         100.000000

# %%
x=train.iloc[:,5:7]
x.head(5)
# Out:
#    Speed_km_hr  DecayOrAccidents
# 0          120                 7
# 1          110                 6
# 2           70                 5
# 3           60                 4
# 4           75                 5

# %%
x.corr()
# Out:
#                   Speed_km_hr  DecayOrAccidents
# Speed_km_hr          1.000000          0.800135
# DecayOrAccidents     0.800135          1.000000

# %%
top10=train["Passenger_satisfaction"].value_counts()[:10]
top10.plot(kind="bar")
plt.title("Passenger satisfaction Graph")
plt.xlabel("Passenger satifaction")
plt.ylabel("No. of trains")
# Out:
# Text(0, 0.5, 'No. of trains')

# %%
z=train[["Train_Name","%_seat_occupied"]].sort_values(by="%_seat_occupied",ascending=False)
z.head(15)
# Out:
#           Train_Name  %_seat_occupied
# 24      DSJ-KK MTY S              100
# 10      PNBE-PTA FTR              100
# 30      ATT-JBP BI-W              100
# 25      PUNE-JBP SPL              100
# 15       LTT-SWV SPL              100
# 11       RSD-PJP BSF              100
# 48      PUNE HTE SPL               97
# 47       MAS SRC SPL               96
# 9       PNBE-BTI FTR               95
# 46       SRC MAS SPL               95
# 23      MAJN-PUNE WE               95
# 3       PALACE ON WH               90
# 18      AJNI-KRMI SP               90
# 5       LKO-SVDK FTR               90
# 12  SVDK VANDEBHARAT               90
